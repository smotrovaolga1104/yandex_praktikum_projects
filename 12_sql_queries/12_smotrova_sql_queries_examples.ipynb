# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#База-данных" data-toc-modified-id="База-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>База данных</a></span></li><li><span><a href="#Запросы-к-базе" data-toc-modified-id="Запросы-к-базе-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Запросы к базе</a></span><ul class="toc-item"><li><span><a href="#Задание" data-toc-modified-id="Задание-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Задание" data-toc-modified-id="Задание-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Задание</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Анализ инвестиционной активности компаний
#
# В данном проекте собраны примены работы с базой данных, которая хранит информацию о венчурных фондах и инвестициях в компании-стартапы. Эта база данных основана на датасете Startup Investments, опубликованном на популярной платформе для соревнований по исследованию данных Kaggle.
#
# ## База данных

# %%
from IPython.display import Image
Image(filename = "C:/Users/1/Downloads/Image.png")

# %% [markdown]
# ## Запросы к базе
#
# ### Задание
#
# Посчитайте, сколько компаний закрылось.

# %% [raw]
# SELECT COUNT(id)
# FROM company
# WHERE status = 'closed';

# %% [markdown]
# ### Задание
#
# Отобразите количество привлечённых средств для новостных компаний США. Используйте данные из таблицы `company`. Отсортируйте таблицу по убыванию значений в поле `funding_total`.

# %% [raw]
# SELECT
#        SUM(funding_total) AS cumulative_funding
# FROM company
# WHERE category_code = 'news'
#       and country_code = 'USA'
# GROUP BY name
# ORDER BY SUM(funding_total) DESC;

# %% [markdown]
# ### Задание
#
# Найдите общую сумму сделок по покупке одних компаний другими в долларах. Отберите сделки, которые осуществлялись только за наличные с 2011 по 2013 год включительно.

# %% [raw]
# SELECT SUM(price_amount)
# FROM acquisition
# WHERE term_code = 'cash'
#       and EXTRACT(YEAR FROM acquired_at) BETWEEN 2011 and 2013;

# %% [markdown]
# ### Задание
#
# Отобразите имя, фамилию и названия аккаунтов людей в твиттере, у которых названия аккаунтов начинаются на 'Silver'.

# %% [raw]
# SELECT first_name,
#        last_name,
#        twitter_username
# FROM people
# WHERE twitter_username LIKE 'Silver%';

# %% [markdown]
# ### Задание
#
# Выведите на экран всю информацию о людях, у которых названия аккаунтов в твиттере содержат подстроку 'money', а фамилия начинается на 'K'.

# %% [raw]
# SELECT *
# FROM people
# WHERE twitter_username LIKE '%money%'
#       and last_name LIKE 'K%';

# %% [markdown]
# ### Задание
#
# Для каждой страны отобразите общую сумму привлечённых инвестиций, которые получили компании, зарегистрированные в этой стране. Страну, в которой зарегистрирована компания, можно определить по коду страны. Отсортируйте данные по убыванию суммы.

# %% [raw]
# SELECT country_code,
#        SUM(funding_total) AS cumulative_funding
# FROM company
# GROUP BY country_code
# ORDER BY cumulative_funding DESC;

# %% [markdown]
# ### Задание
#
# Составьте таблицу, в которую войдёт дата проведения раунда, а также минимальное и максимальное значения суммы инвестиций, привлечённых в эту дату.
# Оставьте в итоговой таблице только те записи, в которых минимальное значение суммы инвестиций не равно нулю и не равно максимальному значению.

# %% [raw]
# SELECT funded_at,
#        MIN(raised_amount) AS min_raised,
#        MAX(raised_amount) AS max_raised
# FROM funding_round
# GROUP BY funded_at
# HAVING MIN(raised_amount) <> 0
#        and MIN(raised_amount) <> MAX(raised_amount);

# %% [markdown]
# ### Задание
#
# Создайте поле с категориями:
# - Для фондов, которые инвестируют в 100 и более компаний, назначьте категорию `high_activity`.
# - Для фондов, которые инвестируют в 20 и более компаний до 100, назначьте категорию `middle_activity`.
# - Если количество инвестируемых компаний фонда не достигает 20, назначьте категорию `low_activity`.
#
# Отобразите все поля таблицы `fund` и новое поле с категориями.

# %% [raw]
# SELECT *,
#        CASE
#            WHEN invested_companies < 20 THEN 'low_activity'
#            WHEN invested_companies < 100 THEN 'middle_activity'
#            ELSE 'high_activity'
#        END
# FROM fund;

# %% [markdown]
# ### Задание
#
# Для каждой из категорий, назначенных в предыдущем задании, посчитайте округлённое до ближайшего целого числа среднее количество инвестиционных раундов, в которых фонд принимал участие. Выведите на экран категории и среднее число инвестиционных раундов. Отсортируйте таблицу по возрастанию среднего.

# %% [raw]
# SELECT CASE
#            WHEN invested_companies>=100 THEN 'high_activity'
#            WHEN invested_companies>=20 THEN 'middle_activity'
#            ELSE 'low_activity'
#        END AS activity,
#        ROUND(AVG(investment_rounds)) AS avg_num_rounds
# FROM fund
# GROUP BY activity
# ORDER BY avg_num_rounds;

# %% [markdown]
# ### Задание
#
# Проанализируйте, в каких странах находятся фонды, которые чаще всего инвестируют в стартапы.
#
# Для каждой страны посчитайте минимальное, максимальное и среднее число компаний, в которые инвестировали фонды этой страны, основанные с 2010 по 2012 год включительно. Исключите страны с фондами, у которых минимальное число компаний, получивших инвестиции, равно нулю. Выгрузите десять самых активных стран-инвесторов.
#
# Отсортируйте таблицу по среднему количеству компаний от большего к меньшему, а затем по коду страны в лексикографическом порядке.

# %% [raw]
# SELECT country_code,
#        MIN(invested_companies) AS min_num_invested,
#        MAX(invested_companies) AS max_num_invested,
#        AVG(invested_companies) AS avg_num_invested
# FROM fund
# WHERE EXTRACT(YEAR FROM founded_at) BETWEEN 2010 and 2012
# GROUP BY country_code
# HAVING MIN(invested_companies) <> 0
# ORDER BY avg_num_invested DESC, country_code
# LIMIT 10;

# %% [markdown]
# ### Задание
#
#
# Отобразите имя и фамилию всех сотрудников стартапов. Добавьте поле с названием учебного заведения, которое окончил сотрудник, если эта информация известна.

# %% [raw]
# SELECT p.first_name,
#        p.last_name,
#        e.instituition
# FROM people AS p
# LEFT JOIN education AS e ON p.id = e.person_id;

# %% [markdown]
# ### Задание
#
# Для каждой компании найдите количество учебных заведений, которые окончили её сотрудники. Выведите название компании и число уникальных названий учебных заведений. Составьте топ-5 компаний по количеству университетов.

# %% [raw]
# SELECT c.name,
#        COUNT(DISTINCT e.instituition) AS num_institutions
# FROM company AS c
# LEFT JOIN people AS p ON c.id = p.company_id
# JOIN education AS e ON p.id = e.person_id
# GROUP BY c.name
# ORDER BY num_institutions DESC
# LIMIT 5;

# %% [markdown]
# ### Задание
#
# Составьте список с уникальными названиями закрытых компаний, для которых первый раунд финансирования оказался последним.

# %% [raw]
# SELECT DISTINCT c.name
# FROM company AS c
# JOIN funding_round AS fr ON c.id = fr.company_id
# WHERE c.status = 'closed'
#       and fr.is_first_round = 1
#       and fr.is_last_round = 1;

# %% [markdown]
# ### Задание
#
# Составьте список уникальных номеров сотрудников, которые работают в компаниях, отобранных в предыдущем задании.

# %% [raw]
# SELECT p.id
# FROM people AS p
# WHERE p.company_id IN (SELECT DISTINCT c.id AS company_id
#                     FROM company AS c
#                     JOIN funding_round AS fr ON c.id = fr.company_id
#                     WHERE c.status = 'closed'
#                           and fr.is_first_round = 1
#                           and fr.is_last_round = 1);

# %% [markdown]
# ### Задание
#
# Составьте таблицу, куда войдут уникальные пары с номерами сотрудников из предыдущей задачи и учебным заведением, которое окончил сотрудник.

# %% [raw]
# SELECT  DISTINCT
#         p.id,
#         e.instituition
# FROM people AS p
# JOIN education AS e ON p.id = e.person_id
# WHERE p.company_id IN (SELECT DISTINCT c.id AS company_id
#                     FROM company AS c
#                     JOIN funding_round AS fr ON c.id = fr.company_id
#                     WHERE c.status = 'closed'
#                           and fr.is_first_round = 1
#                           and fr.is_last_round = 1);

# %% [markdown]
# ### Задание
#
# Посчитайте количество учебных заведений для каждого сотрудника из предыдущего задания. При подсчёте учитывайте, что некоторые сотрудники могли окончить одно и то же заведение дважды.

# %% [raw]
# SELECT p.id AS employee_id,
#        COUNT(e.instituition) AS num_institution
# FROM people AS p
# JOIN education AS e on p.id = e.person_id
# WHERE p.company_id IN (SELECT DISTINCT c.id AS company_id
#                     FROM company AS c
#                     JOIN funding_round AS fr ON c.id = fr.company_id
#                     WHERE c.status = 'closed'
#                           and fr.is_first_round = 1
#                           and fr.is_last_round = 1)
# GROUP BY p.id;

# %% [markdown]
# ### Задание
#
# Дополните предыдущий запрос и выведите среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники разных компаний. Нужно вывести только одну запись, группировка здесь не понадобится.

# %% [raw]
# WITH avg_institutions AS
#     (SELECT p.id AS employee_id,
#            COUNT(e.instituition) AS num_institution
#     FROM people AS p
#     JOIN education AS e on p.id = e.person_id
#     WHERE p.company_id IN (SELECT DISTINCT c.id AS company_id
#                         FROM company AS c
#                         JOIN funding_round AS fr ON c.id = fr.company_id
#                         WHERE c.status = 'closed'
#                               and fr.is_first_round = 1
#                               and fr.is_last_round = 1)
#     GROUP BY p.id)
#
# SELECT AVG(num_institution)
# FROM avg_institutions;

# %% [markdown]
# ### Задание
# Напишите похожий запрос: выведите среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники Facebook*.
#
# *(сервис, запрещённый на территории РФ)

# %% [raw]
# WITH avg_inst AS
#     (SELECT p.id AS employee_id,
#             COUNT(e.instituition) AS num_institution
#     FROM people AS p
#     JOIN education AS e on p.id = e.person_id
#     WHERE p.company_id = (SELECT c.id
#                           FROM company AS c
#                           WHERE c.name = 'Facebook')
#     GROUP BY p.id)
# SELECT AVG(num_institution)
# FROM avg_inst;

# %% [markdown]
# ### Задание
#
# Составьте таблицу из полей:
# - `name_of_fund` — название фонда;
# - `name_of_company` — название компании;
# - `amount` — сумма инвестиций, которую привлекла компания в раунде.
#
# В таблицу войдут данные о компаниях, в истории которых было больше шести важных этапов, а раунды финансирования проходили с 2012 по 2013 год включительно.

# %% [raw]
# SELECT f.name AS name_of_fund,
#        c.name AS name_of_company,
#        fr.raised_amount AS amount
# FROM investment AS i
# JOIN fund AS f ON i.fund_id = f.id
# JOIN company AS c ON i.company_id = c.id
# JOIN funding_round AS fr ON i.funding_round_id = fr.id
# WHERE c.milestones > 6
#       and fr.funded_at BETWEEN '2012-01-01' AND '2013-12-31';

# %% [markdown]
# ### Задание
#
# Выгрузите таблицу, в которой будут такие поля:
# - название компании-покупателя;
# - сумма сделки;
# - название компании, которую купили;
# - сумма инвестиций, вложенных в купленную компанию;
# - доля, которая отображает, во сколько раз сумма покупки превысила сумму вложенных в компанию инвестиций, округлённая до ближайшего целого числа.
#
# Не учитывайте те сделки, в которых сумма покупки равна нулю. Если сумма инвестиций в компанию равна нулю, исключите такую компанию из таблицы.
#
# Отсортируйте таблицу по сумме сделки от большей к меньшей, а затем по названию купленной компании в лексикографическом порядке. Ограничьте таблицу первыми десятью записями.

# %% [raw]
# WITH filt AS (SELECT a.acquiring_company_id,
#                      a.price_amount AS deal_price,
#                      c.name AS target_name,
#                      c.funding_total,
#                      ROUND(a.price_amount / c.funding_total) AS leverage
#               FROM acquisition AS a
#               LEFT JOIN company AS c ON a.acquired_company_id = c.id
#               WHERE a.price_amount <> 0
#                     and c.funding_total <> 0)
# SELECT com.name AS bidder_name,
#        filt.deal_price,
#        filt.target_name,
#        filt.funding_total,
#        filt.leverage
# FROM filt
# LEFT JOIN company AS com ON filt.acquiring_company_id = com.id
# ORDER BY filt.deal_price DESC, filt.target_name
# LIMIT 10;

# %% [markdown]
# ### Задание
#
# Выгрузите таблицу, в которую войдут названия компаний из категории `social`, получившие финансирование с 2010 по 2013 год включительно. Проверьте, что сумма инвестиций не равна нулю. Выведите также номер месяца, в котором проходил раунд финансирования.

# %% [raw]
# SELECT c.name,
#        EXTRACT(MONTH FROM fr.funded_at) AS month
# FROM company AS c
# JOIN funding_round AS fr ON c.id = fr.company_id
# WHERE EXTRACT(YEAR FROM fr.funded_at) BETWEEN 2010 and 2013
#       and fr.raised_amount <> 0
#       and c.category_code = 'social';

# %% [markdown]
# ### Задание
#
# Отберите данные по месяцам с 2010 по 2013 год, когда проходили инвестиционные раунды. Сгруппируйте данные по номеру месяца и получите таблицу, в которой будут поля:
# - номер месяца, в котором проходили раунды;
# - количество уникальных названий фондов из США, которые инвестировали в этом месяце;
# - количество компаний, купленных за этот месяц;
# - общая сумма сделок по покупкам в этом месяце.

# %% [raw]
# WITH rounds AS (SELECT EXTRACT(MONTH FROM fr.funded_at) AS month,
#                        COUNT(DISTINCT f.name) AS num_of_funds
#                 FROM funding_round AS fr
#                 JOIN investment AS i ON fr.id = i.funding_round_id
#                 JOIN fund AS f ON i.fund_id = f.id
#                 WHERE EXTRACT(YEAR FROM fr.funded_at) BETWEEN 2010 and 2013
#                       and f.country_code = 'USA'
#                 GROUP BY EXTRACT(MONTH FROM fr.funded_at)),
#      deals AS
#                (SELECT EXTRACT(MONTH FROM acquired_at) AS month,
#                 COUNT(acquired_company_id) AS num_of_deals,
#                 SUM(price_amount) AS total_deals_value
#                 FROM acquisition
#                 WHERE EXTRACT(YEAR FROM acquired_at) BETWEEN 2010 and 2013
#                 GROUP BY EXTRACT(MONTH FROM acquired_at))
#
# SELECT rounds.month,
#        rounds.num_of_funds,
#        deals.num_of_deals,
#        deals.total_deals_value
# FROM rounds
# JOIN deals ON rounds.month = deals.month;

# %% [markdown]
# ### Задание
#
# Составьте сводную таблицу и выведите среднюю сумму инвестиций для стран, в которых есть стартапы, зарегистрированные в 2011, 2012 и 2013 годах. Данные за каждый год должны быть в отдельном поле. Отсортируйте таблицу по среднему значению инвестиций за 2011 год от большего к меньшему.

# %% [raw]
# WITH y11 AS
#     (SELECT country_code,
#            AVG(funding_total) AS FY11
#     FROM company
#     WHERE EXTRACT(YEAR FROM founded_at) = 2011
#     GROUP BY country_code),
#     y12 AS
#     (SELECT country_code,
#            AVG(funding_total) AS FY12
#     FROM company
#     WHERE EXTRACT(YEAR FROM founded_at) = 2012
#     GROUP BY country_code),
#     y13 AS
#     (SELECT country_code,
#            AVG(funding_total) AS FY13
#     FROM company
#     WHERE EXTRACT(YEAR FROM founded_at) = 2013
#     GROUP BY country_code)
#
# SELECT y11.country_code,
#        y11.FY11,
#        y12.fy12,
#        y13.fy13
# FROM y11
# JOIN y12 ON y11.country_code = y12.country_code
# JOIN y13 ON y11.country_code = y13.country_code
# ORDER BY y11.fy11 DESC;
